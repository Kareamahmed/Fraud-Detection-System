# %% [markdown]
# ## Problem Statement
# Fraudulent transactions across digital services (payments, e-commerce, account
# takeovers) cost our business time and money—and erode customer trust. The ML
# Team has been asked to build an automated fraud-detection tool that flags
# suspicious transactions or user activity in near real time, so that review teams can
# intervene before damage occurs.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read Data

# %%
df = pd.read_csv(r'..\dataset.csv')

# %%
df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df.tail()
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 6362615             0.0   C776919290            0.00       339682.13        1
# 6362616             0.0  C1881841831            0.00            0.00        1
# 6362617             0.0  C1365125890        68488.84      6379898.11        1
# 6362618             0.0  C2080388513            0.00            0.00        1
# 6362619             0.0   C873221189      6510099.11      7360101.63        1
#
#          isFlaggedFraud
# 6362615               0
# 6362616               0
# 6362617               0
# ...

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
df.describe()
# Out:
#                step        amount  oldbalanceOrg  newbalanceOrig  \
# count  6.362620e+06  6.362620e+06   6.362620e+06    6.362620e+06
# mean   2.433972e+02  1.798619e+05   8.338831e+05    8.551137e+05
# std    1.423320e+02  6.038582e+05   2.888243e+06    2.924049e+06
# min    1.000000e+00  0.000000e+00   0.000000e+00    0.000000e+00
# 25%    1.560000e+02  1.338957e+04   0.000000e+00    0.000000e+00
# 50%    2.390000e+02  7.487194e+04   1.420800e+04    0.000000e+00
# 75%    3.350000e+02  2.087215e+05   1.073152e+05    1.442584e+05
# max    7.430000e+02  9.244552e+07   5.958504e+07    4.958504e+07
#
#        oldbalanceDest  newbalanceDest       isFraud  isFlaggedFraud
# count    6.362620e+06    6.362620e+06  6.362620e+06    6.362620e+06
# mean     1.100702e+06    1.224996e+06  1.290820e-03    2.514687e-06
# std      3.399180e+06    3.674129e+06  3.590480e-02    1.585775e-03
# min      0.000000e+00    0.000000e+00  0.000000e+00    0.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %% [markdown]
# # Target Column

# %%
df.isFraud.value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
fraud_counts = df['isFraud'].value_counts()

plt.figure(figsize=(8, 6))
plt.pie(fraud_counts, labels=['Not Fraud (0)', 'Fraud (1)'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon'])
plt.title('Distribution of Fraudulent vs. Non-Fraudulent Transactions')
plt.axis('equal') 
plt.show()

# %% [markdown]
# > Un balanced Data

# %%
df.isFlaggedFraud.value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %% [markdown]
# > no null values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df.type.value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %% [markdown]
# # EDA

# %%
df.type.value_counts().plot(kind='bar',title='Transaction Types' , color = "Skyblue")
plt.xlabel('Transaction Types')
plt.ylabel('Count')
plt.show()

# %%
fraud_by_type = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_type.plot(kind='bar' , title='Fraud Rate By Type ', color = 'salmon')
plt.ylabel('Fraud Rate')
plt.show()

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
df['balanceDiffOrg'] = df.oldbalanceOrg - df.newbalanceOrig
df['balanceDiffDest'] = df.newbalanceDest - df.oldbalanceDest

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOrg', 'balanceDiffDest'],
#       dtype='object')

# %%
(df.balanceDiffOrg < 0 ).sum()
# Out:
# np.int64(1399253)

# %%
(df.balanceDiffDest < 0 ).sum()
# Out:
# np.int64(1238864)

# %%
frauds_pre_step =  df [ df ['isFraud'] == 1 ]['step'].value_counts().sort_index()
plt.plot(frauds_pre_step.index , frauds_pre_step.values )
plt.title( 'Frauds Over Time ')
plt.ylabel('Number Of Fraud')
plt.xlabel('Time')
plt.show()

# %% [markdown]
# > Not Depending On the Time

# %%
df.drop(columns='step' , inplace=True)

# %%
df.head()
# Out:
#        type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2  TRANSFER    181.00  C1305486145          181.0            0.00
# 3  CASH_OUT    181.00   C840083671          181.0            0.00
# 4   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0
#
#    balanceDiffOrg  balanceDiffDest
# 0         9839.64              0.0
# 1         1864.28              0.0
# ...

# %%
top_senders = df.nameOrig.value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C1677795071    3
# C1999539787    3
# C724452879     3
# C1976208114    3
# C400299098     3
# C1784010646    3
# C1530544995    3
# C1065307291    3
# C545315117     3
# C1902386530    3
# Name: count, dtype: int64

# %%
top_receivers = df.nameDest.value_counts().head(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    113
# C985934102     109
# C665576141     105
# C2083562754    102
# C248609774     101
# C1590550415    101
# C1789550256     99
# C451111351      99
# C1360767589     98
# C1023714065     97
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud', 'balanceDiffOrg', 'balanceDiffDest'],
#       dtype='object')

# %%
df.drop(columns=['nameOrig','nameDest','isFlaggedFraud'] , axis=1 , inplace=True)

# %%
df.head()
# Out:
#        type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0   PAYMENT   9839.64       170136.0       160296.36             0.0
# 1   PAYMENT   1864.28        21249.0        19384.72             0.0
# 2  TRANSFER    181.00          181.0            0.00             0.0
# 3  CASH_OUT    181.00          181.0            0.00         21182.0
# 4   PAYMENT  11668.14        41554.0        29885.86             0.0
#
#    newbalanceDest  isFraud  balanceDiffOrg  balanceDiffDest
# 0             0.0        0         9839.64              0.0
# 1             0.0        0         1864.28              0.0
# 2             0.0        1          181.00              0.0
# 3             0.0        1          181.00         -21182.0
# 4             0.0        0        11668.14              0.0

# %%
# separate classes
df_0 = df[df['isFraud'] == 0]
df_1 = df[df['isFraud'] == 1]

# undersample class 0 to match class 1
df_0_under = df_0.sample(n=len(df_1), random_state=42)

# combine
df_under = pd.concat([df_0_under, df_1])

# shuffle
df_under = df_under.sample(frac=1, random_state=42)

# check balance
df_under['isFraud'].value_counts()
# Out:
# isFraud
# 1    8213
# 0    8213
# Name: count, dtype: int64

# %%
fraud_counts = df_under['isFraud'].value_counts()

plt.figure(figsize=(4, 4))
plt.pie(fraud_counts, labels=['Not Fraud (0)', 'Fraud (1)'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon'])
plt.title('Distribution of Fraudulent vs. Non-Fraudulent Transactions')
plt.axis('equal') 
plt.show()

# %% [markdown]
# # Modeling

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from imblearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
categorical = ["type"]

numeric = [
    "amount",
    "oldbalanceOrg",
    "newbalanceOrig",
    "oldbalanceDest",
    "newbalanceDest",
    "balanceDiffDest",
    "balanceDiffOrg"
]

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline(steps=[
    ("prep", preprocessor),
    ("clf", RandomForestClassifier( ))
])

# %% [markdown]
# # Split DataSet

# %%
X = df_under.drop("isFraud", axis=1)
y = df_under["isFraud"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %% [markdown]
# # Train

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest',
#                                                    'balanceDiffDest',
#                                                    'balanceDiffOrg']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['type'])])),
#                 ('clf', RandomForestClassifier())])

# %% [markdown]
# # Evaluation

# %% [markdown]
# #### Train Accuracy

# %%
y_pred_train = pipeline.predict(X_train)
print(f"Accuracy for train: {accuracy_score(y_train,y_pred_train)*100}")
# Out:
# Accuracy for train: 100.0

# %% [markdown]
# #### Test Accuracy

# %%
y_pred_test = pipeline.predict(X_test)
print(f"Accuracy for test: {accuracy_score(y_test,y_pred_test)*100}")
# Out:
# Accuracy for test: 99.47240259740259

# %% [markdown]
# ## Confusion Matrix

# %%
sns.heatmap(confusion_matrix(y_test, y_pred_test) , annot=True ,cmap="Blues", fmt='d' , xticklabels=['Not Fraud' ,'Fraud'], yticklabels=['Not Fraud' ,'Fraud'])
plt.ylabel("Actual Label")
plt.xlabel("Predict Label")
plt.show()

# %%
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2464
#            1       0.99      1.00      0.99      2464
#
#     accuracy                           0.99      4928
#    macro avg       0.99      0.99      0.99      4928
# weighted avg       0.99      0.99      0.99      4928

# %%
from sklearn.metrics import roc_auc_score

y_train_pred_proba = pipeline.predict_proba(X_train)[:, 1]
y_test_pred_proba = pipeline.predict_proba(X_test)[:, 1]

roc_auc_train = roc_auc_score(y_train, y_train_pred_proba)
roc_auc_test = roc_auc_score(y_test, y_test_pred_proba)

print(f"ROC AUC for training data: {roc_auc_train}")
print(f"ROC AUC for test data: {roc_auc_test}")
# Out:
# ROC AUC for training data: 1.0
# ROC AUC for test data: 0.9992761018405296

# %% [markdown]
# #### ROC Curve

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plot ROC curve for training data
RocCurveDisplay.from_predictions(y_train, y_train_pred_proba, name=f"Train ROC AUC: {roc_auc_train:.2f}", ax=plt.gca())

# Plot ROC curve for test data
RocCurveDisplay.from_predictions(y_test, y_test_pred_proba, name=f"Test ROC AUC: {roc_auc_test:.2f}", ax=plt.gca())

plt.title('ROC Curve for Fraud Detection Model')
plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Save Model

# %%
import joblib 
joblib.dump(pipeline , 'fraud_detection_model.pkl')
# Out:
# ['fraud_detection_model.pkl']

# %% [markdown]
# # Another Model (Logistic Regression)

# %%
pipeline_LR = Pipeline(steps=[
    ("prep", preprocessor),
    ("clf", LogisticRegression( ))
])

# %%
pipeline_LR.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest',
#                                                    'balanceDiffDest',
#                                                    'balanceDiffOrg']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['type'])])),
#                 ('clf', LogisticRegression())])

# %%
y_pred_train = pipeline_LR.predict(X_train)
print(f"Accuracy for train: {accuracy_score(y_train,y_pred_train)*100}")
# Out:
# Accuracy for train: 93.39015480953209

# %%
y_pred_test = pipeline_LR.predict(X_test)
print(f"Accuracy for test: {accuracy_score(y_test,y_pred_test)*100}")
# Out:
# Accuracy for test: 93.54707792207793

# %% [markdown]
# > _____________________________________________________________________________________________________

# %%
X_test.head()
# Out:
#              type      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 3832099  CASH_OUT   310612.06           0.00             0.0       321988.04
# 6054551  TRANSFER   797710.80      797710.80             0.0            0.00
# 1163632  TRANSFER   768520.15      768520.15             0.0            0.00
# 410905   TRANSFER  1102133.90     1102133.90             0.0            0.00
# 6039455  TRANSFER   548677.33      548677.33             0.0            0.00
#
#          newbalanceDest  balanceDiffOrg  balanceDiffDest
# 3832099       632600.10            0.00        310612.06
# 6054551            0.00       797710.80             0.00
# 1163632            0.00       768520.15             0.00
# 410905        746575.95      1102133.90        746575.95
# 6039455            0.00       548677.33             0.00

# %%
y_test.head()
# Out:
# 3832099    0
# 6054551    1
# 1163632    1
# 410905     1
# 6039455    1
# Name: isFraud, dtype: int64
